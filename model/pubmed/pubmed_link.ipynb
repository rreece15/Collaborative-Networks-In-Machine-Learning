# %% [markdown]
# ## Import Statements

# %%
import stellargraph as sg
from stellargraph.data import EdgeSplitter
from stellargraph.mapper import FullBatchLinkGenerator
from stellargraph.layer import GCN, LinkEmbedding

import tensorflow as tf
from tensorflow import keras
from sklearn import preprocessing, feature_extraction, model_selection

from stellargraph import globalvar
from stellargraph import datasets
from IPython.display import display, HTML
# %matplotlib inline

# %% [markdown]
# ## Getting the Data

# %%
dataset = datasets.PubMedDiabetes()
display(HTML(dataset.description))
G, _subjects = dataset.load()
print(G.info())
# Out:
# The PubMed Diabetes dataset consists of 19717 scientific publications from PubMed database pertaining to diabetes classified into one of three classes. The citation network consists of 44338 links. Each publication in the dataset is described by a TF/IDF weighted word vector from a dictionary which consists of 500 unique words.
# StellarGraph: Undirected multigraph
#  Nodes: 19717, Edges: 44338
#
#  Node types:
#   paper: [19717]
#     Features: float32 vector, length 500
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [44338]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ## GNN Link Prediction

# %%
# Define an edge splitter on the original graph G:
edge_splitter_test = EdgeSplitter(G)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from G, and obtain the
# reduced graph G_test with the sampled links removed:
G_test, edge_ids_test, edge_labels_test = edge_splitter_test.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 4433 positive and 4433 negative edges. **

# %%
# Define an edge splitter on the reduced graph G_test:
edge_splitter_train = EdgeSplitter(G_test)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from G_test, and obtain the
# reduced graph G_train with the sampled links removed:
G_train, edge_ids_train, edge_labels_train = edge_splitter_train.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 3990 positive and 3990 negative edges. **

# %%
epochs = 50

# %%
train_gen = FullBatchLinkGenerator(G_train, method="gcn")
train_flow = train_gen.flow(edge_ids_train, edge_labels_train)
# Out:
# Using GCN (local pooling) filters...

# %%
test_gen = FullBatchLinkGenerator(G_test, method="gcn")
test_flow = train_gen.flow(edge_ids_test, edge_labels_test)
# Out:
# Using GCN (local pooling) filters...

# %%
gcn = GCN(
    layer_sizes=[16, 16], activations=["relu", "relu"], generator=train_gen, dropout=0.3
)

# %%
x_inp, x_out = gcn.in_out_tensors()

# %%
prediction = LinkEmbedding(activation="relu", method="ip")(x_out)

# %%
prediction = keras.layers.Reshape((-1,))(prediction)

# %%
model = keras.Model(inputs=x_inp, outputs=prediction)

history = model.compile(
    optimizer=keras.optimizers.Adam(lr=0.01),
    loss=keras.losses.binary_crossentropy,
    metrics=[tf.keras.metrics.BinaryAccuracy()],
)
# Out:
# c:\Users\reece\miniconda3\envs\tensorflow_cpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
init_train_metrics = model.evaluate(train_flow)
init_test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 1s 505ms/step - loss: 4.0553 - binary_accuracy: 0.5000
# 1/1 [==============================] - 0s 149ms/step - loss: 4.0657 - binary_accuracy: 0.5000
#
# Train Set Metrics of the initial (untrained) model:
# 	loss: 4.0553
# 	binary_accuracy: 0.5000
#
# Test Set Metrics of the initial (untrained) model:
# 	loss: 4.0657
# 	binary_accuracy: 0.5000

# %%
history = model.fit(
    train_flow, epochs=epochs, validation_data=test_flow, verbose=2, shuffle=False
)
# Out:
# Epoch 1/50
# 1/1 - 2s - loss: 3.9811 - binary_accuracy: 0.5000 - val_loss: 2.1006 - val_binary_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 2/50
# 1/1 - 0s - loss: 2.0943 - binary_accuracy: 0.5000 - val_loss: 1.4349 - val_binary_accuracy: 0.5000 - 269ms/epoch - 269ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 1.4303 - binary_accuracy: 0.5000 - val_loss: 1.0441 - val_binary_accuracy: 0.5016 - 286ms/epoch - 286ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 1.0367 - binary_accuracy: 0.5015 - val_loss: 0.7782 - val_binary_accuracy: 0.5232 - 267ms/epoch - 267ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 0.7753 - binary_accuracy: 0.5269 - val_loss: 0.5970 - val_binary_accuracy: 0.6206 - 266ms/epoch - 266ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 0.5895 - binary_accuracy: 0.6292 - val_loss: 0.5114 - val_binary_accuracy: 0.7657 - 267ms/epoch - 267ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 0.5120 - binary_accuracy: 0.7637 - val_loss: 0.5689 - val_binary_accuracy: 0.8269 - 263ms/epoch - 263ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 0.6114 - binary_accuracy: 0.8120 - val_loss: 0.8338 - val_binary_accuracy: 0.7792 - 281ms/epoch - 281ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 0.9261 - binary_accuracy: 0.7456 - val_loss: 1.1043 - val_binary_accuracy: 0.7080 - 265ms/epoch - 265ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 1.1919 - binary_accuracy: 0.6910 - val_loss: 1.1472 - val_binary_accuracy: 0.6887 - 285ms/epoch - 285ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 1.2661 - binary_accuracy: 0.6729 - val_loss: 1.0362 - val_binary_accuracy: 0.7272 - 290ms/epoch - 290ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 1.1400 - binary_accuracy: 0.6975 - val_loss: 0.7994 - val_binary_accuracy: 0.7858 - 327ms/epoch - 327ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 0.9001 - binary_accuracy: 0.7583 - val_loss: 0.6206 - val_binary_accuracy: 0.8157 - 326ms/epoch - 326ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 0.7012 - binary_accuracy: 0.7995 - val_loss: 0.5336 - val_binary_accuracy: 0.8274 - 299ms/epoch - 299ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 0.5790 - binary_accuracy: 0.8134 - val_loss: 0.5021 - val_binary_accuracy: 0.8084 - 328ms/epoch - 328ms/step
# Epoch 16/50
# 1/1 - 0s - loss: 0.5129 - binary_accuracy: 0.8038 - val_loss: 0.4995 - val_binary_accuracy: 0.7752 - 355ms/epoch - 355ms/step
# Epoch 17/50
# 1/1 - 0s - loss: 0.5090 - binary_accuracy: 0.7679 - val_loss: 0.5110 - val_binary_accuracy: 0.7375 - 355ms/epoch - 355ms/step
# Epoch 18/50
# 1/1 - 0s - loss: 0.5173 - binary_accuracy: 0.7331 - val_loss: 0.5294 - val_binary_accuracy: 0.7039 - 364ms/epoch - 364ms/step
# Epoch 19/50
# 1/1 - 0s - loss: 0.5270 - binary_accuracy: 0.7056 - val_loss: 0.5499 - val_binary_accuracy: 0.6744 - 273ms/epoch - 273ms/step
# Epoch 20/50
# 1/1 - 0s - loss: 0.5522 - binary_accuracy: 0.6741 - val_loss: 0.5671 - val_binary_accuracy: 0.6547 - 262ms/epoch - 262ms/step
# Epoch 21/50
# 1/1 - 0s - loss: 0.5622 - binary_accuracy: 0.6579 - val_loss: 0.5775 - val_binary_accuracy: 0.6426 - 248ms/epoch - 248ms/step
# Epoch 22/50
# 1/1 - 0s - loss: 0.5756 - binary_accuracy: 0.6470 - val_loss: 0.5832 - val_binary_accuracy: 0.6383 - 269ms/epoch - 269ms/step
# Epoch 23/50
# 1/1 - 0s - loss: 0.5799 - binary_accuracy: 0.6426 - val_loss: 0.5834 - val_binary_accuracy: 0.6381 - 290ms/epoch - 290ms/step
# Epoch 24/50
# 1/1 - 0s - loss: 0.5810 - binary_accuracy: 0.6412 - val_loss: 0.5787 - val_binary_accuracy: 0.6439 - 309ms/epoch - 309ms/step
# Epoch 25/50
# 1/1 - 0s - loss: 0.5790 - binary_accuracy: 0.6456 - val_loss: 0.5707 - val_binary_accuracy: 0.6529 - 317ms/epoch - 317ms/step
# Epoch 26/50
# 1/1 - 0s - loss: 0.5663 - binary_accuracy: 0.6561 - val_loss: 0.5583 - val_binary_accuracy: 0.6640 - 318ms/epoch - 318ms/step
# Epoch 27/50
# 1/1 - 0s - loss: 0.5542 - binary_accuracy: 0.6689 - val_loss: 0.5436 - val_binary_accuracy: 0.6809 - 250ms/epoch - 250ms/step
# Epoch 28/50
# 1/1 - 0s - loss: 0.5386 - binary_accuracy: 0.6837 - val_loss: 0.5302 - val_binary_accuracy: 0.7019 - 307ms/epoch - 307ms/step
# Epoch 29/50
# 1/1 - 0s - loss: 0.5254 - binary_accuracy: 0.7006 - val_loss: 0.5162 - val_binary_accuracy: 0.7188 - 329ms/epoch - 329ms/step
# Epoch 30/50
# 1/1 - 0s - loss: 0.5127 - binary_accuracy: 0.7234 - val_loss: 0.5029 - val_binary_accuracy: 0.7366 - 267ms/epoch - 267ms/step
# Epoch 31/50
# 1/1 - 0s - loss: 0.5049 - binary_accuracy: 0.7355 - val_loss: 0.4930 - val_binary_accuracy: 0.7537 - 266ms/epoch - 266ms/step
# Epoch 32/50
# 1/1 - 0s - loss: 0.4956 - binary_accuracy: 0.7539 - val_loss: 0.4901 - val_binary_accuracy: 0.7682 - 249ms/epoch - 249ms/step
# Epoch 33/50
# 1/1 - 0s - loss: 0.5005 - binary_accuracy: 0.7739 - val_loss: 0.4882 - val_binary_accuracy: 0.7841 - 259ms/epoch - 259ms/step
# Epoch 34/50
# 1/1 - 0s - loss: 0.5072 - binary_accuracy: 0.7840 - val_loss: 0.4891 - val_binary_accuracy: 0.7945 - 265ms/epoch - 265ms/step
# Epoch 35/50
# 1/1 - 0s - loss: 0.5053 - binary_accuracy: 0.7964 - val_loss: 0.4922 - val_binary_accuracy: 0.8039 - 251ms/epoch - 251ms/step
# Epoch 36/50
# 1/1 - 0s - loss: 0.5129 - binary_accuracy: 0.7982 - val_loss: 0.4886 - val_binary_accuracy: 0.8032 - 265ms/epoch - 265ms/step
# Epoch 37/50
# 1/1 - 0s - loss: 0.5012 - binary_accuracy: 0.7945 - val_loss: 0.4878 - val_binary_accuracy: 0.8024 - 278ms/epoch - 278ms/step
# Epoch 38/50
# 1/1 - 0s - loss: 0.5032 - binary_accuracy: 0.7982 - val_loss: 0.4873 - val_binary_accuracy: 0.8019 - 320ms/epoch - 320ms/step
# Epoch 39/50
# 1/1 - 0s - loss: 0.5080 - binary_accuracy: 0.7980 - val_loss: 0.4869 - val_binary_accuracy: 0.8015 - 361ms/epoch - 361ms/step
# Epoch 40/50
# 1/1 - 0s - loss: 0.5009 - binary_accuracy: 0.7987 - val_loss: 0.4866 - val_binary_accuracy: 0.8000 - 437ms/epoch - 437ms/step
# Epoch 41/50
# 1/1 - 0s - loss: 0.4999 - binary_accuracy: 0.7957 - val_loss: 0.4853 - val_binary_accuracy: 0.7989 - 356ms/epoch - 356ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 0.5046 - binary_accuracy: 0.7986 - val_loss: 0.4848 - val_binary_accuracy: 0.7989 - 362ms/epoch - 362ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 0.5085 - binary_accuracy: 0.7985 - val_loss: 0.4857 - val_binary_accuracy: 0.7966 - 339ms/epoch - 339ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 0.4999 - binary_accuracy: 0.7936 - val_loss: 0.4867 - val_binary_accuracy: 0.7945 - 429ms/epoch - 429ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 0.4926 - binary_accuracy: 0.7887 - val_loss: 0.4853 - val_binary_accuracy: 0.7934 - 380ms/epoch - 380ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 0.4957 - binary_accuracy: 0.7955 - val_loss: 0.4840 - val_binary_accuracy: 0.7896 - 314ms/epoch - 314ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 0.5038 - binary_accuracy: 0.7865 - val_loss: 0.4844 - val_binary_accuracy: 0.7892 - 317ms/epoch - 317ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 0.5030 - binary_accuracy: 0.7895 - val_loss: 0.4838 - val_binary_accuracy: 0.7869 - 352ms/epoch - 352ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 0.4907 - binary_accuracy: 0.7862 - val_loss: 0.4837 - val_binary_accuracy: 0.7867 - 384ms/epoch - 384ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 0.4917 - binary_accuracy: 0.7850 - val_loss: 0.4832 - val_binary_accuracy: 0.7874 - 398ms/epoch - 398ms/step

# %%
sg.utils.plot_history(history)

# %%
train_metrics = model.evaluate(train_flow)
test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 0s 134ms/step - loss: 0.4851 - binary_accuracy: 0.7927
# 1/1 [==============================] - 0s 132ms/step - loss: 0.4832 - binary_accuracy: 0.7874
#
# Train Set Metrics of the trained model:
# 	loss: 0.4851
# 	binary_accuracy: 0.7927
#
# Test Set Metrics of the trained model:
# 	loss: 0.4832
# 	binary_accuracy: 0.7874
